# %% [markdown]
# <a href="https://colab.research.google.com/github/coraagg/CDS524_Assignment1_ZHANG-Chenguo/blob/main/CF1_CTP_MW_Runs.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 步骤1：安装依赖
# !pip install pymoo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# 步骤2：从 GitHub 拉取
# !git clone https://github.com/coraagg/CDS526-Casestudy
# %cd CDS526-Casestudy
# Out:
# Cloning into 'CDS526-Casestudy'...
# remote: Enumerating objects: 415, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (396/396), done.
# remote: Total 415 (delta 53), reused 39 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (415/415), 5.25 MiB | 11.54 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /content/CDS526-Casestudy

# %%
# 步骤3：运行实验（小规模测试）
import numpy as np
import random
from problem import get_problem
from nsga2_aos import NSGA2_AOS
# 测试单个问题，2 runs，50 代
problem = get_problem('cf1')
algo = NSGA2_AOS(problem, pop_size=50, max_gen=50)
algo.run()
print(f"Final IGD: {algo.igd_history[-1]}")
# Out:
# Gen 50, IGD: 0.5242, Nondominated: 50
# Final IGD: 0.5241634047544307

# %%
# 步骤4：正式运行（挂载 Drive 保存结果）
from google.colab import drive
drive.mount('/content/drive')

# 修改 run_experiments.py 中的保存路径
import run_experiments as re
re.run_experiments(['cf1', 'ctp1'], n_runs=30, max_gen=200)
# Out:
# Mounted at /content/drive
#
# === Running cf1 ===
#   Run 1/5
# Gen 50, IGD: 0.5268, Nondominated: 50
# Gen 100, IGD: 0.2696, Nondominated: 100
#   Run 2/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4689/821274460.py in <cell line: 0>()
#       5 # 修改 run_experiments.py 中的保存路径
#       6 import run_experiments as re
# ----> 7 re.run_experiments(['cf1', 'ctp1'], n_runs=5, max_gen=100)
#
# /content/CDS526-Casestudy/run_experiments.py in run_experiments(problem_list, n_runs, max_gen)
#      51         for run in range(n_runs):
#      52             print(f"  Run {run+1}/{n_runs}")
# ---> 53             res = run_single_run(problem, run, max_gen=max_gen)
#      54             all_results.append(res)
#      55
#
# /content/CDS526-Casestudy/run_experiments.py in run_single_run(problem_name, run_id, pop_size, max_gen)
# ...
